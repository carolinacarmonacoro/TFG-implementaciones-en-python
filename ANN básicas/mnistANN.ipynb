# %% [markdown]
# IMPLEMENTACIÓN DE UNA ANN BÁSICA CON LA API KERAS DE TENSORFLOW

# %% [markdown]
# Desarrollamos el entrenamiento de una red neuronal para clasificación con 2 capas ocultas (300 neuronas la primera y 100 la segunda), ambas con función de activación ReLU. La capa de salida es una capa softmax con 10 neuronas.
#
# Usamos el dataset MNIST (clasificación de imágenes de números entre 0-9).

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# Vamos a hacer el modelo con inicialización aleatoria de los pesos, pero se pueden hacer otras inicializaciones.

# %%
#Cargamos y normalizamos MNIST (píxeles de 0-255 a 0-1)
mnist = keras.datasets.mnist
(X_train_full, y_train_full), (X_test_full, y_test) = mnist.load_data() #datasets conocidos como el MNIST ya vienen dividios en Train/Set oficialmente
#Escalamos y creamos un conjunto de validación:

X_valid,X_train=X_train_full[:5000]/255.0, X_train_full[5000:]/255.0
y_valid,y_train=y_train_full[:5000],y_train_full[5000:]
X_test=X_test_full/255.0 


#Definimos la arquitectura de la red (300 neuronas ReLU -> 100 neuronas ReLU -> 10 Softmax)
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]), #Aplana la imagen de 28x28 a 784 para tenerla como lista de inputs en vez de matriz.
    keras.layers.Dense(300, activation="relu"), #Usamos Dense para que las capas estén totalmente conectadas
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])

model.summary()
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 300)            │       235,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        30,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 266,610 (1.02 MB)
#  Trainable params: 266,610 (1.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Ahora hay que definir la función de coste que usaremos para entrenar la red: la entropía cruzada. Esta función penalizará a los modelos que asignan una probabilidad baja a la clase correcta.
#
# Además actualizamos los pesos con el descenso de gradiente estocástico.
#
# El último paso es especificar cómo evaluaremos el modelo: usaremos la precisión (porcentaje de predicciones correctas).

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])     #da porcentaje de aciertos

# %% [markdown]
# El entrenamiento se organiza en épocas (recorrido completo por todo el conjunto de entrenamiento). Dentro de cada época la red procesa varios mini-batches. Para cada batch (lote) se ejecuta el entrenamiento para ajustar los pesos. Al final de cada época se mide la precisión tanto en los datos de entrenamiento como en los de validación.

# %%
history=model.fit(X_train, y_train, batch_size=50,epochs=30, validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step - accuracy: 0.8098 - loss: 0.7680 - val_accuracy: 0.9012 - val_loss: 0.3646
# Epoch 2/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 672us/step - accuracy: 0.9066 - loss: 0.3355 - val_accuracy: 0.9180 - val_loss: 0.2850
# Epoch 3/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 679us/step - accuracy: 0.9206 - loss: 0.2808 - val_accuracy: 0.9284 - val_loss: 0.2490
# Epoch 4/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 686us/step - accuracy: 0.9300 - loss: 0.2471 - val_accuracy: 0.9350 - val_loss: 0.2223
# Epoch 5/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 675us/step - accuracy: 0.9368 - loss: 0.2224 - val_accuracy: 0.9430 - val_loss: 0.2016
# Epoch 6/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 690us/step - accuracy: 0.9428 - loss: 0.2022 - val_accuracy: 0.9486 - val_loss: 0.1863
# Epoch 7/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 678us/step - accuracy: 0.9473 - loss: 0.1850 - val_accuracy: 0.9522 - val_loss: 0.1720
# Epoch 8/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 690us/step - accuracy: 0.9507 - loss: 0.1700 - val_accuracy: 0.9550 - val_loss: 0.1638
# Epoch 9/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 700us/step - accuracy: 0.9547 - loss: 0.1570 - val_accuracy: 0.9594 - val_loss: 0.1532
# Epoch 10/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 682us/step - accuracy: 0.9582 - loss: 0.1457 - val_accuracy: 0.9614 - val_loss: 0.1434
# Epoch 11/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 679us/step - accuracy: 0.9609 - loss: 0.1358 - val_accuracy: 0.9634 - val_loss: 0.1346
# Epoch 12/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 691us/step - accuracy: 0.9636 - loss: 0.1274 - val_accuracy: 0.9664 - val_loss: 0.1272
# Epoch 13/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 689us/step - accuracy: 0.9657 - loss: 0.1193 - val_accuracy: 0.9672 - val_loss: 0.1218
# Epoch 14/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 710us/step - accuracy: 0.9681 - loss: 0.1122 - val_accuracy: 0.9698 - val_loss: 0.1162
# Epoch 15/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 691us/step - accuracy: 0.9701 - loss: 0.1060 - val_accuracy: 0.9704 - val_loss: 0.1123
# Epoch 16/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 695us/step - accuracy: 0.9719 - loss: 0.1003 - val_accuracy: 0.9716 - val_loss: 0.1091
# Epoch 17/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 687us/step - accuracy: 0.9737 - loss: 0.0950 - val_accuracy: 0.9724 - val_loss: 0.1041
# Epoch 18/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 698us/step - accuracy: 0.9749 - loss: 0.0899 - val_accuracy: 0.9726 - val_loss: 0.1022
# Epoch 19/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 688us/step - accuracy: 0.9763 - loss: 0.0854 - val_accuracy: 0.9742 - val_loss: 0.0981
# Epoch 20/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 684us/step - accuracy: 0.9775 - loss: 0.0812 - val_accuracy: 0.9746 - val_loss: 0.0943
# Epoch 21/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 689us/step - accuracy: 0.9783 - loss: 0.0775 - val_accuracy: 0.9744 - val_loss: 0.0925
# Epoch 22/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 685us/step - accuracy: 0.9795 - loss: 0.0734 - val_accuracy: 0.9764 - val_loss: 0.0899
# Epoch 23/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 703us/step - accuracy: 0.9804 - loss: 0.0705 - val_accuracy: 0.9764 - val_loss: 0.0901
# Epoch 24/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 679us/step - accuracy: 0.9813 - loss: 0.0672 - val_accuracy: 0.9764 - val_loss: 0.0869
# Epoch 25/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 691us/step - accuracy: 0.9824 - loss: 0.0643 - val_accuracy: 0.9774 - val_loss: 0.0862
# Epoch 26/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 685us/step - accuracy: 0.9830 - loss: 0.0615 - val_accuracy: 0.9766 - val_loss: 0.0853
# Epoch 27/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 714us/step - accuracy: 0.9841 - loss: 0.0588 - val_accuracy: 0.9780 - val_loss: 0.0818
# Epoch 28/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 672us/step - accuracy: 0.9849 - loss: 0.0562 - val_accuracy: 0.9782 - val_loss: 0.0816
# Epoch 29/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 688us/step - accuracy: 0.9856 - loss: 0.0541 - val_accuracy: 0.9788 - val_loss: 0.0785
# Epoch 30/30
# 1100/1100 ━━━━━━━━━━━━━━━━━━━━ 1s 679us/step - accuracy: 0.9865 - loss: 0.0517 - val_accuracy: 0.9782 - val_loss: 0.0798

# %% [markdown]
# Vemos que entre el conjunto de entrenamiento y el de validación no hay mucha diferencia en cuanto a accuracy, lo cual es bueno, ya que el caso contrario podría indicar overfitting.
#
# History contiene los parámetros de entrenamiento, la lista de épocas, y la pérdida y la precisión en cada época en los conjuntos de entrenamiento y validación. Podemos visualizar las curvas de aprendizaje:

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) #eje y entre 0 y 1
plt.show()

# %%
#Evaluamos en el test set (para estimar error de generalización):
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Precisión en test: {test_acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - accuracy: 0.9744 - loss: 0.0832
# Precisión en test: 0.9744

# %% [markdown]
# Vemos que hay muy buena precisión en el conjunto de prueba, es un buen modelo.

# %%
import numpy as np
#Tomamos las primeras 5 imágenes del conjunto de test
X_nuevas = X_test[:5]
y_reales = y_test[:5]

#El modelo predice las probabilidades para cada clase (0-9)
y_predicciones_prop = model.predict(X_nuevas)

# Elegimos la clase con la probabilidad más alta usando argmax
y_predicciones_clase = np.argmax(y_predicciones_prop, axis=1)
print("\n--- Comparación de resultados individuales ---")
for i in range(5):
    print(f"Entrada (Imagen {i}): Predicción -> {y_predicciones_clase[i]} | Valor Real -> {y_reales[i]}")

#Clasifica las 5 correctamente
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# --- Comparación de resultados individuales ---
# Entrada (Imagen 0): Predicción -> 7 | Valor Real -> 7
# Entrada (Imagen 1): Predicción -> 2 | Valor Real -> 2
# Entrada (Imagen 2): Predicción -> 1 | Valor Real -> 1
# Entrada (Imagen 3): Predicción -> 0 | Valor Real -> 0
# Entrada (Imagen 4): Predicción -> 4 | Valor Real -> 4
